# %% [markdown]
# ## Matching Click Sequences

# %% [markdown]
# ### Scope

# %% [markdown]
# The aim of the task is the matching between contact and respond json segments according to the syntactic similarity or even better the semantic similarity of their content. However, human language is complex, and the semantic meaning of an utterance is usually dependent upon the context at a given time and learnt experience of the meaning of the words that are used. This is particularly challenging when automatically understanding the meaning of texting, which can contain non-standard language.

# %% [markdown]
# ### Data content approach

# %% [markdown]
# The body of the json files seems to be separated into actions, each of these presents information about event type, element name and text value. The first two fields are indicating mostly the user-computer interaction and the third text value reveals a lot of information about the main content/reason of the contact or the respond which can help us to decide where it belongs. Thus, the algorithm who implemented collects and groups into one big string the values of the text_value elements. For example:

# %% [raw]
# Contact[0] = 2005X-3045B-1569J 67A23B Dear Ms. A, can you confirm your purchase of a plane ticket to Hong Kong?
# Respond[2] = Ms. A approved purchase of a plane ticket to Hong Kong, purchase number: 2005X-3045B-1569J.

# %% [markdown]
# ### Importing data manipulation libraries

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Importing Natural language Processing libraries

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Function implementation section

# %%
def extract_value_text(data):
    """
    Description:
        Extracts the values of each field of the json, but returns 
        only a unified string of the text_values after grouping.
    Input Parameters
        data: json data [contact or respond data] 
    Output Parameters
        _txt_str: String 
    """
    _txt = []
    _evnt = []
    _elm = []
    _misc =[]
    for i in range(len(data)): 
        for key, value in data[i].items(): 
            if key == 'text_value':
                _txt.append(value)
            else:
                _misc.append(value)
    _txt_str=' '.join(_txt) 

    return _txt_str

# %%
def string_constractor(data, kind):
    """
    Description:
        Composes the unified strings into lists and gives
        a tag according to the kind of data that red
    Input Parameters
        data: json data [contact or respond data] 
        kind: String 
    Output Parameters
        text: List
        tag: List 
    """
    text = []
    tag = []
    for i in range(len(data)):
        text.append(extract_value_text(data[i]))
        tag.append(kind + str(i))
    return text , tag

# %%
def df_constructor(text_c, tag_c, text_r, tag_r):
    """
    Description:
        Composes a dataframe from lists 
    Input Parameters
        text_c: List
        tag_c: List 
        text_r: List
        tag_r: List
    Output Parameters
        df: Dataframe
    """
    text = []
    tag = []
    text = text_c + text_r
    tag = tag_c + tag_r

    df = pd.DataFrame({'text': text, 'tag': tag })
    return df

# %%
def heatmap(df, mtx):
    """
    Description:
        Visualizes the cosine similarity between the inputs 
    Input Parameters
        df: Dataframe
        mtx: 2D Array 
    """
    x_labels = df['text'].tolist()
    y_labels = df['text'].tolist()

    fig, ax = plt.subplots()
    im = ax.imshow(mtx)

    ax.set_xticks(np.arange(len(x_labels)))
    ax.set_yticks(np.arange(len(y_labels)))
    ax.set_xticklabels(x_labels)
    ax.set_yticklabels(y_labels)

    plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')

    for i in range(len(y_labels)):
        for j in range(len(x_labels)):
            text = ax.text(j, i, '%.2f'%mtx[i, j], ha='center', va='center', color='w', fontsize=6)

   # fig.tight_layout()
    plt.show()

# %%
def preprocess_text(doc):
    """
    Description:
        Preprocesses each document into a proper 
        format to to pass it on TfidfVectorizer
    Input Parameters
        doc: String
    """
    tokeniser = RegexpTokenizer(r'\w+')
    tokens = tokeniser.tokenize(doc)
    
    lemmatiser = WordNetLemmatizer()
    lemmas = [lemmatiser.lemmatize(token.lower(), pos='v') for token in tokens]
    
    keywords= [lemma for lemma in lemmas if lemma not in stopwords.words('english')]
    return keywords

# %%
def feature_matrix_tf_idf(df):
    """
    Description:
        Preprocess texts and Constracts a feature matrix
    Input Parameters
        df: Dataframe
    Output Parameters
        X_ftr: Compressed sparse row matrix 
    """
    corpus = df['text'].tolist()

    vectoriser = TfidfVectorizer(analyzer=preprocess_text)
    X_ftr = vectoriser.fit_transform(corpus)

    return X_ftr

# %%
def pairwise_cosine_similarity(X_ftr):
    """
    Description:
        Measures the similarity between two non-zero 
        vectors of an inner product space
    Input Parameters
        X_ftr: Compressed sparse row matrix 
    Output Parameters
        res: 2d Array
    """
    pairwise_similarity = X_ftr * X_ftr.T
    res = pairwise_similarity.toarray()

    return res

# %%
def query_res(corr, df):
    """
    Description:
        Finds the index of the most similar document 
    Input Parameters
        corr: 2d Array
        df: Dataframe
    Output Parameters
        qdf: Dataframe
    """
    corpus = df['text'].tolist()

    np.fill_diagonal(corr, np.nan)
    flt = df[df['tag'].str.contains('contact',regex = False)]
    n = len(flt)
    lst = []
    for idx in range(len(flt)):

        query_idx = corpus.index(flt['text'][idx])       
        result_idx = np.nanargmax(corr[query_idx])
        score = corr.item(query_idx,result_idx)

        lst.append([df['tag'][query_idx],df['tag'][result_idx],score ])
        res = pd.DataFrame(lst, columns =['contact', 'response', 'score'])    
        qdf = res[res['response'].str.contains('respond ',regex = False)]

        #if result_idx >= n:
        #    score = corr.item(query_idx,result_idx)
        #    lst.append([df['tag'][query_idx],df['tag'][result_idx],score ])
        #    res = pd.DataFrame(lst, columns =['contact', 'response', 'score'])    

    return qdf

# %% [markdown]
# ### Main body of the algorithm

# %%
if __name__ == '__main__':
    
    cd = os.getcwd()

    try:
        print(' - [ ? ] Loading test data')
        with open(cd+r"\data.json") as json_file: 
            data = json.load(json_file)

        contact =[]
        respond = []
        contact = data['contact']
        respond = data['respond']
        print('   [ V ] Successfully complete')
    except Exception as e:
        print(e)
        print('   [ X ] Failed. Application exits...')
# Out:
#  - [ ? ] Loading test data
#    [ V ] Successfully complete

# %% [markdown]
# ### Pre-processing

# %%
    try:
        print(' - [ ? ] Preparing the text_value into a uniform string')
        text_c, tag_c = string_constractor(contact, 'contact ')
        text_r, tag_r = string_constractor(respond, 'respond ')
        print('   [ V ] Successfully complete')
    except Exception as e:
        print(e)
# Out:
#  - [ ? ] Preparing the text_value into a uniform string
#    [ V ] Successfully complete

# %%
    try:
        print(' - [ ? ] Constructing a dataframe')
        df = df_constructor(text_c, tag_c, text_r, tag_r)
        print(df)
        print('   [ V ] Successfully complete')
    except Exception as e:
        print(e)
# Out:
#  - [ ? ] Constructing a dataframe
#                                                 text        tag
# 0  2005X-3045B-1569J 67A23B Dear Ms. A, can you c...  contact 0
# 1  3865T-0665J-5443D E43AC2 Dear Mr. B, can you c...  contact 1
# 2  9834K-1239Y-8733N 983D1C Dear Mrs. C, can you ...  contact 2
# 3  Mrs. C approved purchase of a plane ticket to ...  respond 0
# 4  Mr. B rejected purchase of a meal in Hong Kong...  respond 1
# 5  Ms. A approved purchase of a plane ticket to H...  respond 2
#    [ V ] Successfully complete

# %% [markdown]
# ### Term Frequency–Inverse Document Frequency (tf-idf)

# %% [markdown]
# In order to proceed into count vectorize and tf-idf representation and finally, to pairwise cosine similarity, the input corpus needs to be pre-processed with tokenizing, normalizing, and stop words removing, then we can fit to the data and transform to a feature matrix.

# %%
    try:
        print(' - [ ? ] Creating a feature matrix of words\'s frequencies')
        X_train = feature_matrix_tf_idf(df)
        print('   [ V ] Successfully complete')
    except Exception as e:
        print(e)
# Out:
#  - [ ? ] Creating a feature matrix of words's frequencies
#    [ V ] Successfully complete

# %% [markdown]
# ### Pairwise Cosine Similarity

# %%
    try:
        print(' - [ ? ] Calculating the cosine similarity array')
        corr = pairwise_cosine_similarity(X_train) 
        print(corr)
        print('   [ V ] Successfully complete')
    except Exception as e:
        print(e)
# Out:
#  - [ ? ] Calculating the cosine similarity array
# [[1.         0.28321752 0.27034024 0.1619527  0.16589065 0.73101562]
#  [0.28321752 1.         0.16000584 0.05535968 0.73851827 0.17019244]
#  [0.27034024 0.16000584 1.         0.77836839 0.05412749 0.16245416]
#  [0.1619527  0.05535968 0.77836839 1.         0.17662095 0.39686157]
#  [0.16589065 0.73851827 0.05412749 0.17662095 1.         0.30312016]
#  [0.73101562 0.17019244 0.16245416 0.39686157 0.30312016 1.        ]]
#    [ V ] Successfully complete

# %% [markdown]
# ### Results

# %%
    try:
        print(' - [ ? ] Vissualizing the similarity array')
        heatmap(df, corr)
        print('   [ V ] Successfully complete')
    except Exception as e:
        print(e)
# Out:
#  - [ ? ] Vissualizing the similarity array
#    [ V ] Successfully complete

# %%
    try:
        print(' - [ ? ] Matching the contact/respond segments with the max similarity')
        print(query_res(corr, df))
        print('   [ V ] Successfully complete')
        print('')
    except Exception as e:
        print(e)
# Out:
#  - [ ? ] Matching the contact/respond segments with the max similarity
#      contact   response     score
# 0  contact 0  respond 2  0.731016
# 1  contact 1  respond 1  0.738518
# 2  contact 2  respond 0  0.778368
#    [ V ] Successfully complete

# %% [markdown]
# ### Limitations of the implementation

# %% [markdown]
# 1.	It relies mainly in syntactic similarity
# 2.	In case of no match we don’t get result like: contact 2  | X |  0.0000
